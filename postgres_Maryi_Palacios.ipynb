# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('ObesityDataSet.csv')
print(df.head())
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.describe(include = 'all')
# Out:
#        Gender          Age       Height       Weight  \
# count    2111  2111.000000  2111.000000  2111.000000
# unique      2          NaN          NaN          NaN
# top      Male          NaN          NaN          NaN
# freq     1068          NaN          NaN          NaN
# mean      NaN    24.312600     1.701677    86.586058
# std       NaN     6.345968     0.093305    26.191172
# min       NaN    14.000000     1.450000    39.000000
# 25%       NaN    19.947192     1.630000    65.473343
# 50%       NaN    22.777890     1.700499    83.000000
# 75%       NaN    26.000000     1.768464   107.430682
# max       NaN    61.000000     1.980000   173.000000
#
#        family_history_with_overweight  FAVC         FCVC          NCP  \
# count                            2111  2111  2111.000000  2111.000000
# unique                              2     2          NaN          NaN
# top                               yes   yes          NaN          NaN
# ...

# %%
df.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# ...

# %% [markdown]
# ### Loading data

# %%
df.shape
# Out:
# (2111, 17)

# %%
#!pip install psycopg2

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
# Note:: The make sure you use the information from your specific PostgreSQL installation
host = r'127.0.0.1' # denotes that the db in a local installation
db = r'MSDS610' # db we just created
user = r'postgres' # using the postgres user for this demo
pw = r'7205458456' # this is the password established during installation
port = r'5432' # default port estabalished during install
schema = r'raw' # schema we just created

# %%
db_conn = create_engine("postgresql://{}:{}@{}:{}/{}".format(user, pw, host, port, db))

# %%
from sqlalchemy import text
with db_conn.connect() as conn:
    sql = text("select tables.table_name from information_schema.tables where table_schema = :schema order by 1;")
    tbl_df = pd.read_sql(sql, conn, params={'schema': schema})
print(tbl_df)
# Out:
# Empty DataFrame
# Columns: [table_name]
# Index: []

# %%
from sqlalchemy import text
sql_check = text("SELECT * FROM information_schema.tables WHERE table_schema = :schema;")
with db_conn.connect() as conn:
    tbl_check_df = pd.read_sql(sql_check, conn, params={'schema': schema})
print(tbl_check_df)
# Out:
# Empty DataFrame
# Columns: [table_catalog, table_schema, table_name, table_type, self_referencing_column_name, reference_generation, user_defined_type_catalog, user_defined_type_schema, user_defined_type_name, is_insertable_into, is_typed, commit_action]
# Index: []

# %%
table_name = r'Obesity_data'

# %%
df.to_sql(table_name, con=db_conn, if_exists='replace', index=False, schema=schema, chunksize=1000, method='multi')
# Out:
# 2111

# %%
from sqlalchemy import text
sql = text("SELECT tables.table_name FROM information_schema.tables WHERE table_schema = :schema ORDER BY 1;")
with db_conn.connect() as conn:
    tbl_df = pd.read_sql(sql, conn, params={'schema': schema}, index_col=None)
print(tbl_df)
# Out:
#      table_name
# 0  Obesity_data

# %%
print(type(db_conn))
# Out:
# <class 'sqlalchemy.engine.base.Engine'>

# %%
obesity_check.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN    None
# 4       3450.0  Female
# 5       3650.0    Male
# ...
